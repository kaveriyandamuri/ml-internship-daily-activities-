# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\yvsur\Downloads\temp.csv")
df
# Out:
#         city  humidity  temperature
# 0  Hyderabad      25.0         65.0
# 1  Hyderabad       NaN         22.0
# 2  Hyderabad      45.0          NaN
# 3   kakinada      32.0         12.0
# 4   kakinada       NaN         65.0
# 5   kakinada      66.0          NaN
# 6    chennai      31.0         34.0
# 7      vizag      56.0         77.0
# 8      vizag      12.0         23.0
# 9   banglore      34.0         11.0

# %%
df.isnull()
# Out:
#     city  humidity  temperature
# 0  False     False        False
# 1  False      True        False
# 2  False     False         True
# 3  False     False        False
# 4  False      True        False
# 5  False     False         True
# 6  False     False        False
# 7  False     False        False
# 8  False     False        False
# 9  False     False        False

# %%
df.isnull().sum()
# Out:
# city           0
# humidity       2
# temperature    2
# dtype: int64

# %%
df_clean=df.dropna()

# %%
df_clean
# Out:
#         city  humidity  temperature
# 0  Hyderabad      25.0         65.0
# 3   kakinada      32.0         12.0
# 6    chennai      31.0         34.0
# 7      vizag      56.0         77.0
# 8      vizag      12.0         23.0
# 9   banglore      34.0         11.0

# %%
df
# Out:
#         city  humidity  temperature
# 0  Hyderabad      25.0         65.0
# 1  Hyderabad       NaN         22.0
# 2  Hyderabad      45.0          NaN
# 3   kakinada      32.0         12.0
# 4   kakinada       NaN         65.0
# 5   kakinada      66.0          NaN
# 6    chennai      31.0         34.0
# 7      vizag      56.0         77.0
# 8      vizag      12.0         23.0
# 9   banglore      34.0         11.0

# %%
df_clean
# Out:
#         city  humidity  temperature
# 0  Hyderabad      25.0         65.0
# 3   kakinada      32.0         12.0
# 6    chennai      31.0         34.0
# 7      vizag      56.0         77.0
# 8      vizag      12.0         23.0
# 9   banglore      34.0         11.0

# %%
df["humidity"]=df["humidity"].fillna(10)
df
# Out:
#         city  humidity  temperature
# 0  Hyderabad      25.0         65.0
# 1  Hyderabad      10.0         22.0
# 2  Hyderabad      45.0         10.0
# 3   kakinada      32.0         12.0
# 4   kakinada      10.0         65.0
# 5   kakinada      66.0         10.0
# 6    chennai      31.0         34.0
# 7      vizag      56.0         77.0
# 8      vizag      12.0         23.0
# 9   banglore      34.0         11.0

# %%
df["temperature"]=df["temperature"].fillna(df.temperature.mean())
df
# Out:
#         city  humidity  temperature
# 0  Hyderabad      25.0         65.0
# 1  Hyderabad      10.0         22.0
# 2  Hyderabad      45.0         10.0
# 3   kakinada      32.0         12.0
# 4   kakinada      10.0         65.0
# 5   kakinada      66.0         10.0
# 6    chennai      31.0         34.0
# 7      vizag      56.0         77.0
# 8      vizag      12.0         23.0
# 9   banglore      34.0         11.0

# %%
import pandas as pd
df=pd.DataFrame({
    "name":["kaveri","niha","sweety","ramya","prash"],
    "rollno":[3,9,54,52,41]
})
df
# Out:
#      name  rollno
# 0  kaveri       3
# 1    niha       9
# 2  sweety      54
# 3   ramya      52
# 4   prash      41
