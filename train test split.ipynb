# %% [markdown]
# # What is Train Test split
#           Train test split is a data preperation technique where we divide the dataset into:
#
#           Training data: Used to train the ML model
#           Testing data: Used to evaluate how well the model performs on unseen data.
#
# # why do we need train test split
#           If we train and test on the same data, the model
#           - looks smart
#           - Fails in real world data
#           Train test split helps to:
#           - Detect overfitting
#           - Measure Real performance
#           - Simulate future/unseen data
# # real life analogy
#           Studying from a book (train) != writing exam questions you have already seen
#
# # Common split ratio
#           Training         Testing           when to use
#           --------         --------          -----------
#           80%               20%               Standard choice
#           70%               30%               Small datasets
#           90%               10%               Large datasets
#
# # Example
#           If N=100 and Split=80:20
#                 Train= 80 samples
#                 Test= 20 samples

# %% [markdown]
# ![ml%20pic.png](attachment:ml%20pic.png)

# %%
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
data=pd.DataFrame({
    "studyhours":[1,2,3,4,5,6,7,8],
    "marks":[35,40,50,55,65,70,80,85]
})
data
# Out:
#    studyhours  marks
# 0           1     35
# 1           2     40
# 2           3     50
# 3           4     55
# 4           5     65
# 5           6     70
# 6           7     80
# 7           8     85

# %%
X=data[["studyhours"]] #input data
Y=data["marks"] #output data

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.20,random_state=40) #0.20=20% (random state) not necessary. it is for shuffle and train data

# %%
X_train
# Out:
#    studyhours
# 2           3
# 4           5
# 0           1
# 5           6
# 3           4
# 6           7

# %%
X_test
# Out:
#    studyhours
# 7           8
# 1           2

# %%
X_train.shape
# Out:
# (6, 1)

# %%
X_test.shape
# Out:
# (2, 1)

# %%
Y_train.shape
# Out:
# (6,)

# %%
Y_test.shape
# Out:
# (2,)

# %% [markdown]
# # Real time dataset

# %%
diabetes=pd.read_csv(r"https://github.com/YBIFoundation/Dataset/raw/main/Diabetes.csv")

# %%
diabetes
# Out:
#      pregnancies  glucose  diastolic  triceps  insulin   bmi    dpf  age  \
# 0              6      148         72       35        0  33.6  0.627   50
# 1              1       85         66       29        0  26.6  0.351   31
# 2              8      183         64        0        0  23.3  0.672   32
# 3              1       89         66       23       94  28.1  0.167   21
# 4              0      137         40       35      168  43.1  2.288   33
# ..           ...      ...        ...      ...      ...   ...    ...  ...
# 763           10      101         76       48      180  32.9  0.171   63
# 764            2      122         70       27        0  36.8  0.340   27
# 765            5      121         72       23      112  26.2  0.245   30
# 766            1      126         60        0        0  30.1  0.349   47
# 767            1       93         70       31        0  30.4  0.315   23
#
#      diabetes
# 0           1
# 1           0
# 2           1
# 3           0
# ...

# %%
diabetes.columns
# Out:
# Index(['pregnancies', 'glucose', 'diastolic', 'triceps', 'insulin', 'bmi',
#        'dpf', 'age', 'diabetes'],
#       dtype='object')

# %%
y=diabetes["diabetes"]

# %%
x=diabetes.drop(["diabetes"],axis=1)

# %%
x=diabetes[["pregnancies","glucose","diastolic","triceps","insulin","bmi","dpf","age"]]
y=diabetes["diabetes"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=40)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((614, 8), (154, 8), (614,), (154,))
